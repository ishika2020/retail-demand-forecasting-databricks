# %%
dbutils.notebook.run("01_bronze_ingestion", timeout_seconds=600)
dbutils.notebook.run("02_silver_transform", timeout_seconds=600)
dbutils.notebook.run("03_gold_aggregation", timeout_seconds=600)
dbutils.notebook.run("04_ml_demand_forecast", timeout_seconds=600)
